# %%
# !pip install arabic-reshaper
# Out:
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.0-py3-none-any.whl.metadata (12 kB)
# Downloading arabic_reshaper-3.0.0-py3-none-any.whl (20 kB)
# Installing collected packages: arabic-reshaper
# Successfully installed arabic-reshaper-3.0.0

# %%
# !pip install presidio_analyzer
# !pip install presidio-anonymizer
# !pip install python-bidi
# !pip install langchain-experimental
# Out:
# Requirement already satisfied: presidio_analyzer in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (2.2.355)
# Requirement already satisfied: phonenumbers<9.0.0,>=8.12 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from presidio_analyzer) (8.13.45)
# Requirement already satisfied: pyyaml in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from presidio_analyzer) (6.0.2)
# Requirement already satisfied: regex in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from presidio_analyzer) (2023.12.25)
# Requirement already satisfied: spacy<4.0.0,>=3.4.4 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from presidio_analyzer) (3.7.6)
# Requirement already satisfied: tldextract in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from presidio_analyzer) (5.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.7.4)
# Requirement already satisfied: jinja2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.26.4)
# Requirement already satisfied: idna in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from tldextract->presidio_analyzer) (3.8)
# Requirement already satisfied: requests-file>=1.4 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from tldextract->presidio_analyzer) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from tldextract->presidio_analyzer) (3.15.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4.0.0,>=3.4.4->presidio_analyzer) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.1.5)
# Requirement already satisfied: colorama in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from jinja2->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4.0.0,>=3.4.4->presidio_analyzer) (0.1.2)
# Requirement already satisfied: presidio-anonymizer in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (2.2.355)
# Requirement already satisfied: azure-core in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from presidio-anonymizer) (1.31.0)
# Requirement already satisfied: pycryptodome>=3.10.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from presidio-anonymizer) (3.20.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from azure-core->presidio-anonymizer) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from azure-core->presidio-anonymizer) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from azure-core->presidio-anonymizer) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests>=2.21.0->azure-core->presidio-anonymizer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests>=2.21.0->azure-core->presidio-anonymizer) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests>=2.21.0->azure-core->presidio-anonymizer) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests>=2.21.0->azure-core->presidio-anonymizer) (2024.8.30)
# Collecting python-bidi
#   Downloading python_bidi-0.6.3-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Downloading python_bidi-0.6.3-cp311-none-win_amd64.whl (157 kB)
# Installing collected packages: python-bidi
# Successfully installed python-bidi-0.6.3
# Requirement already satisfied: langchain-experimental in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (0.0.65)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.16 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-experimental) (0.2.16)
# Collecting langchain-core<0.3.0,>=0.2.38 (from langchain-experimental)
#   Downloading langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (0.6.7)
# Collecting langchain<0.3.0,>=0.2.16 (from langchain-community<0.3.0,>=0.2.16->langchain-experimental)
#   Downloading langchain-0.2.17-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-community<0.3.0,>=0.2.16->langchain-experimental) (8.4.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-experimental) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-experimental) (2.7.4)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langchain-core<0.3.0,>=0.2.38->langchain-experimental) (4.12.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.9.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.38->langchain-experimental) (3.0.0)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.16->langchain-community<0.3.0,>=0.2.16->langchain-experimental)
#   Using cached langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.38->langchain-experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.38->langchain-experimental) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from requests<3,>=2->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (3.0.3)
# Requirement already satisfied: anyio in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (3.7.1)
# Requirement already satisfied: httpcore==1.* in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\administrator\miniconda3\envs\idk\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.16->langchain-experimental) (1.0.0)
# Downloading langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Downloading langchain-0.2.17-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 49.3 MB/s eta 0:00:00
# Using cached langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# Installing collected packages: langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.15
#     Uninstalling langchain-core-0.3.15:
#       Successfully uninstalled langchain-core-0.3.15
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.1
#     Uninstalling langchain-text-splitters-0.3.1:
#       Successfully uninstalled langchain-text-splitters-0.3.1
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.5
#     Uninstalling langchain-0.3.5:
#       Successfully uninstalled langchain-0.3.5
# Successfully installed langchain-0.2.17 langchain-core-0.2.43 langchain-text-splitters-0.2.4
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000243F704E310>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000243F7086C10>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000243F7087590>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed')': /simple/langchain-core/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000243F709C150>: Failed to establish a new connection: [Errno 11004] getaddrinfo failed')': /simple/langchain-core/
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# crewai 0.35.8 requires langchain<0.2.0,>=0.1.4, but you have langchain 0.2.17 which is incompatible.
# crewai-tools 0.3.0 requires chromadb<0.5.0,>=0.4.22, but you have chromadb 0.5.16 which is incompatible.
# crewai-tools 0.3.0 requires langchain<0.2.0,>=0.1.4, but you have langchain 0.2.17 which is incompatible.
# embedchain 0.1.113 requires chromadb<0.5.0,>=0.4.24, but you have chromadb 0.5.16 which is incompatible.
# embedchain 0.1.113 requires langchain<0.2.0,>=0.1.4, but you have langchain 0.2.17 which is incompatible.
# embedchain 0.1.113 requires pypdf<5.0.0,>=4.0.1, but you have pypdf 5.1.0 which is incompatible.
# langchain-google-genai 2.0.3 requires langchain-core<0.4,>=0.3.13, but you have langchain-core 0.2.43 which is incompatible.
# langchain-google-vertexai 2.0.7 requires langchain-core<0.4,>=0.3.15, but you have langchain-core 0.2.43 which is incompatible.
# langchain-ollama 0.2.0 requires langchain-core<0.4.0,>=0.3.0, but you have langchain-core 0.2.43 which is incompatible.
# langchain-pinecone 0.2.0 requires langchain-core<0.4,>=0.3, but you have langchain-core 0.2.43 which is incompatible.
# praisonai-tools 0.0.8 requires chromadb<0.5.0,>=0.4.22, but you have chromadb 0.5.16 which is incompatible.
# praisonai-tools 0.0.8 requires langchain<0.2.0,>=0.1.4, but you have langchain 0.2.17 which is incompatible.

# %%
from presidio_analyzer import Pattern, PatternRecognizer
from presidio_anonymizer.entities import OperatorConfig
from langchain_experimental.data_anonymizer import PresidioReversibleAnonymizer
import arabic_reshaper
from bidi.algorithm import get_display
import re

# %%
class ArabicPIIAgent:
    def __init__(self):
        self.anonymizer = PresidioReversibleAnonymizer(
            analyzed_fields=[
                "ARABIC_NAME",
                "PHONE_NUMBER",
                "ADDRESS",
                "EMAIL_ADDRESS",
                "NATIONAL_ID",
            ],
            add_default_faker_operators=False,
        )
        self._add_recognizers()

    def _add_recognizers(self):

        arabic_name_pattern = Pattern(
            name="arabic_name_pattern",
            regex=r'(?:السيد|السيدة|الدكتور|الأستاذ)?\s*[\u0600-\u06FF\s]{3,40}',
            score=0.85,
        )
        self.anonymizer.add_recognizer(
            PatternRecognizer(
                supported_entity="ARABIC_NAME",
                patterns=[arabic_name_pattern]
            )
        )


        phone_pattern = Pattern(
            name="uae_phone",
            regex=r'(?:\+971|00971|971)?[0-5]\d{8}',
            score=0.95
        )
        self.anonymizer.add_recognizer(
            PatternRecognizer(
                supported_entity="PHONE_NUMBER",
                patterns=[phone_pattern]
            )
        )

        email_pattern = Pattern(
            name="email_pattern",
            regex=r'[\w\.-]+@[\w\.-]+\.[a-zA-Z]{2,}',
            score=0.95
        )
        self.anonymizer.add_recognizer(
            PatternRecognizer(
                supported_entity="EMAIL_ADDRESS",
                patterns=[email_pattern]
            )
        )

        emirates_id_pattern = Pattern(
            name="emirates_id_pattern",
            regex=r'784-\d{4}-\d{7}-\d',
            score=0.95
        )
        self.anonymizer.add_recognizer(
            PatternRecognizer(
                supported_entity="NATIONAL_ID",
                patterns=[emirates_id_pattern]
            )
        )

        address_pattern = Pattern(
            name="arabic_address",
            regex=r'(?:شارع|طريق|حي|منطقة)[\u0600-\u06FF\s،,٠-٩0-9]{5,100}',
            score=0.8
        )
        self.anonymizer.add_recognizer(
            PatternRecognizer(
                supported_entity="ADDRESS",
                patterns=[address_pattern]
            )
        )

    def mask(self, text):
        """Mask PII in Arabic text"""
        return self.anonymizer.anonymize(text)

    def unmask(self, anonymized_text):
        """Unmask previously anonymized Arabic text"""
        return self.anonymizer.deanonymize(anonymized_text)

# %%
sample_text = """
    محضر اجتماع
    ------------------
    التاريخ: 15 نوفمبر 2023

    الحاضرون:
    1. السيد محمد عبدالله الهاشمي
    رقم الهوية: 784-1234-1234567-1
    رقم الهاتف: +971501234567
    البريد الإلكتروني: mohammed@example.com
    العنوان: شارع الشيخ زايد، منطقة الوحدة، أبوظبي

    2. السيدة فاطمة أحمد الكعبي
    رقم الهوية: 784-5678-7654321-2
    رقم الهاتف: +971562345678
    البريد الإلكتروني: fatima@company.ae
    العنوان: شارع خليفة، منطقة النهدة، دبي

    موضوع الاجتماع: مناقشة المشروع الجديد
    """

# %%
try:
      pii_agent = ArabicPIIAgent()

      print("Original Text:")
      print("-" * 50)
      print(sample_text)
      print("\n")

      masked_text = pii_agent.mask(sample_text)
      print("Masked Text:")
      print("-" * 50)
      print(masked_text)
      print("\n")


      unmasked_text = pii_agent.unmask(masked_text)
      print("Unmasked Text:")
      print("-" * 50)
      print(unmasked_text)

except Exception as e:
      print(f"An error occurred: {str(e)}")
# Out:
# Original Text:
# --------------------------------------------------
#
#     محضر اجتماع
#     ------------------
#     التاريخ: 15 نوفمبر 2023
#
#     الحاضرون:
#     1. السيد محمد عبدالله الهاشمي
#     رقم الهوية: 784-1234-1234567-1
#     رقم الهاتف: +971501234567
#     البريد الإلكتروني: mohammed@example.com
#     العنوان: شارع الشيخ زايد، منطقة الوحدة، أبوظبي
#
#     2. السيدة فاطمة أحمد الكعبي
#     رقم الهوية: 784-5678-7654321-2
#     رقم الهاتف: +971562345678
#     البريد الإلكتروني: fatima@company.ae
#     العنوان: شارع خليفة، منطقة النهدة، دبي
#
#     موضوع الاجتماع: مناقشة المشروع الجديد
#
#
#
# Masked Text:
# --------------------------------------------------
# <ARABIC_NAME>------------------<ARABIC_NAME_2>: 15<ARABIC_NAME_3>2023<ARABIC_NAME_4>:<ARABIC_NAME_5>1. السيد محمد عبدالله الهاشمي<ARABIC_NAME_5>رقم الهوية: <NATIONAL_ID><ARABIC_NAME_5>رقم الهاتف: <PHONE_NUMBER><ARABIC_NAME_5>البريد الإلكتروني: <EMAIL_ADDRESS><ARABIC_NAME_5>العنوان: شارع الشيخ زايد، منطقة الوحدة، أبوظبي
# <ARABIC_NAME_5>2. السيدة فاطمة أحمد الكعبي<ARABIC_NAME_5>رقم الهوية: <NATIONAL_ID_2><ARABIC_NAME_5>رقم الهاتف: <PHONE_NUMBER_2><ARABIC_NAME_5>البريد الإلكتروني: <EMAIL_ADDRESS_2><ARABIC_NAME_5>العنوان: شارع خليفة، منطقة النهدة، دبي
# <ARABIC_NAME_5>موضوع الاجتماع: مناقشة المشروع الجديد<ARABIC_NAME_5>
#
#
# Unmasked Text:
# --------------------------------------------------
#
#     محضر اجتماع
#     ------------------
#     التاريخ: 15 نوفمبر 2023
#
#     الحاضرون:
#     1. السيد محمد عبدالله الهاشمي
#     رقم الهوية: 784-1234-1234567-1
#     رقم الهاتف: +971501234567
#     البريد الإلكتروني: mohammed@example.com
#     العنوان: شارع الشيخ زايد، منطقة الوحدة، أبوظبي
#
#     2. السيدة فاطمة أحمد الكعبي
#     رقم الهوية: 784-5678-7654321-2
#     رقم الهاتف: +971562345678
#     البريد الإلكتروني: fatima@company.ae
#     العنوان: شارع خليفة، منطقة النهدة، دبي
#
#     موضوع الاجتماع: مناقشة المشروع الجديد
